# %%
# !ls
# Out:
# lenta.txt  rapido.txt  Untitled.ipynb  wordList.wav
# lenta.wav  rapido.wav  wordList.txt

# %%
import librosa
import matplotlib.pyplot as plt

# %%
F1="lenta.wav"
F2="rapido.wav"
F3="wordList.wav"

y1, sr = librosa.load(F1, sr=16000)
y2, sr = librosa.load(F2, sr=16000)
y3, sr = librosa.load(F3, sr=16000)

# %% [markdown]
# # PALABRAS VELOCIDAD LENTA

# %%
plt.plot(y1)

# %% [markdown]
# # PALABRAS  VELOCIDAD RAPIDA

# %%
plt.plot(y2)

# %% [markdown]
# # PALABRAS VELOCIDAD NORMAL

# %%
plt.plot(y3)
