# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from glob import glob

import librosa
import librosa.display
import IPython.display as ipd

#TO MAKE PLOTS LOOK NICER
from itertools import cycle
sns.set_theme(style="white", palette=None)
color_pal= plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle= cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
data_files=glob('*.m4a')
data_files
alcon, sr = librosa.load(data_files[0])
black, sr = librosa.load(data_files[1])
colibrie, sr = librosa.load(data_files[2])
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/librosa/util/decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)

# %% [markdown]
# ### ALCON

# %%
f=alcon
audio=data_files[0]
n=len(f)
fhat=np.fft.fft(f/n)
PSD= fhat * np.conj(fhat)/n 
dt=1/n
t = np.arange(0,1,dt)
freq = (1/(dt*n))*np.arange(n)
L = np.arange(1,np.floor(n/2), dtype='int')
ipd.Audio(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mp4;base64,..." type="audio/mp4" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, axs= plt.subplots(2,1)

plt.sca(axs[0])
plt.plot(t,f,color='c', label='Noisy')
plt.xlim(t[0], t[-1])
plt.legend

plt.sca(axs[1])
plt.plot(freq[L],PSD[L],color='c', label='Noisy')
plt.xlim(freq[L[0]], freq[L[-1]])
plt.xlabel('Frecuency in HZ')
plt.ylabel('Power Spectrum')
plt.legend
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# DENOISING

# %%
L
# Out:
# array([      1,       2,       3, ..., 2003197, 2003198, 2003199])

# %%
PSD[-1000:]
# Out:
# array([9.15246625e-20+0.j, 2.08582259e-19+0.j, 1.09111094e-18+0.j,
#        2.50787366e-19+0.j, 6.71902923e-19+0.j, 6.75857998e-19+0.j,
#        1.98160522e-19+0.j, 4.14060360e-19+0.j, 9.76660688e-19+0.j,
#        2.94145959e-19+0.j, 4.23145296e-19+0.j, 1.52109466e-18+0.j,
#        5.84167589e-19+0.j, 4.97888006e-19+0.j, 2.04239111e-18+0.j,
#        2.00440226e-19+0.j, 3.18726390e-19+0.j, 2.94001629e-18+0.j,
#        1.50141132e-18+0.j, 1.09496615e-18+0.j, 2.38939801e-18+0.j,
#        1.68588616e-18+0.j, 2.30873830e-18+0.j, 3.82637922e-18+0.j,
#        9.56672962e-19+0.j, 1.04759846e-18+0.j, 3.10258140e-18+0.j,
#        8.45547693e-19+0.j, 9.39365204e-19+0.j, 4.26804865e-18+0.j,
#        1.80047435e-18+0.j, 1.28505421e-18+0.j, 3.12561114e-18+0.j,
#        1.25344572e-18+0.j, 6.25910847e-19+0.j, 2.62673504e-18+0.j,
#        1.28840353e-18+0.j, 6.34325558e-19+0.j, 1.79069621e-18+0.j,
#        8.69170054e-19+0.j, 1.04355928e-18+0.j, 2.01984393e-18+0.j,
#        5.33257185e-19+0.j, 5.03955447e-19+0.j, 2.08480383e-18+0.j,
#        6.58133849e-19+0.j, 7.93309466e-19+0.j, 1.67532260e-18+0.j,
#        4.50551404e-18+0.j, 3.74594045e-18+0.j, 5.39830658e-18+0.j,
#        4.66562963e-18+0.j, 4.77109353e-18+0.j, 4.98196394e-18+0.j,
#        4.17694157e-18+0.j, 6.88424449e-18+0.j, 6.74063366e-18+0.j,
#        4.91431939e-18+0.j, 8.20026371e-18+0.j, 1.05121196e-17+0.j,
#        6.20529682e-18+0.j, 7.50701540e-18+0.j, 8.95077159e-18+0.j,
#        5.95222226e-18+0.j, 7.75272188e-18+0.j, 8.49323405e-18+0.j,
#        6.54932132e-18+0.j, 5.49801282e-18+0.j, 7.61746248e-18+0.j,
#        4.44565467e-18+0.j, 4.40820438e-18+0.j, 6.35778949e-18+0.j,
#        4.34955932e-18+0.j, 4.16335369e-18+0.j, 6.82290833e-18+0.j,
#        5.81044872e-18+0.j, 4.12487839e-18+0.j, 5.53336225e-18+0.j,
#        6.82069540e-18+0.j, 4.95394639e-18+0.j, 4.40713169e-18+0.j,
#        6.54595434e-18+0.j, 6.93366806e-18+0.j, 5.11880538e-18+0.j,
#        6.26994555e-18+0.j, 5.59346683e-18+0.j, 4.12151060e-18+0.j,
#        3.67095483e-18+0.j, 4.79173206e-18+0.j, 5.40193383e-18+0.j,
#        3.11481529e-18+0.j, 3.68788832e-18+0.j, 6.10972570e-18+0.j,
#        2.93327585e-18+0.j, 3.25314463e-18+0.j, 5.72638954e-18+0.j,
#        4.15424807e-18+0.j, 3.72036062e-18+0.j, 7.08074688e-18+0.j,
#        5.95636960e-18+0.j, 3.86816124e-18+0.j, 6.21453921e-18+0.j,
#        6.45625049e-18+0.j, 4.27608169e-18+0.j, 4.62459117e-18+0.j,
#        6.07953517e-18+0.j, 4.26106243e-18+0.j, 5.11045878e-18+0.j,
#        5.92464138e-18+0.j, 4.34489629e-18+0.j, 2.92753973e-18+0.j,
#        5.26397297e-18+0.j, 4.36107706e-18+0.j, 2.05209876e-18+0.j,
#        3.15174145e-18+0.j, 4.71495941e-18+0.j, 2.74190951e-18+0.j,
#        3.37369998e-18+0.j, 5.36549654e-18+0.j, 2.91009127e-18+0.j,
#        2.53674348e-18+0.j, 5.03531387e-18+0.j, 4.82053647e-18+0.j,
#        3.21654692e-18+0.j, 3.79120837e-18+0.j, 5.58601361e-18+0.j,
#        4.47861720e-18+0.j, 4.17413996e-18+0.j, 3.96524129e-18+0.j,
#        3.39831422e-18+0.j, 1.90432533e-18+0.j, 3.51278649e-18+0.j,
#        4.24711413e-18+0.j, 1.33746264e-18+0.j, 3.22835266e-18+0.j,
#        4.08821459e-18+0.j, 2.39855070e-18+0.j, 1.84448392e-18+0.j,
#        4.58198025e-18+0.j, 2.61326278e-18+0.j, 2.33376643e-18+0.j,
#        5.22635413e-18+0.j, 2.89387640e-18+0.j, 1.74519829e-18+0.j,
#        5.07312325e-18+0.j, 3.62395223e-18+0.j, 1.50724013e-18+0.j,
#        3.38430053e-18+0.j, 3.38153574e-18+0.j, 2.02601865e-18+0.j,
#        3.06711878e-18+0.j, 2.95500569e-18+0.j, 2.84634084e-18+0.j,
#        6.13932835e-19+0.j, 1.40354258e-18+0.j, 5.28388064e-19+0.j,
#        1.63537826e-18+0.j])

# %%
freq
# Out:
# array([0.000000e+00, 1.000000e+00, 2.000000e+00, ..., 4.006397e+06,
#        4.006398e+06, 4.006399e+06])

# %%
indices = PSD >0 #find all frecuencies with  large power
PSDclean = PSD * indices #Zero out all others
fhat = indices * fhat # Zero out small Fourier coeffs in Y

ffilt = np.fft.ifft(fhat)  #Inverse FFT for filtered time signal

# %%
plt.plot(PSD)

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(t,f,color='c', label='Noisy')
plt.xlim(t[0], t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(t,ffilt,color='k', label='Filtered')
plt.xlim(t[0], t[-1])
plt.legend()

plt.sca(axs[2])
plt.plot(freq[L],PSD[L],color='c', label='Noisy')
plt.plot(freq[L],PSDclean[L], color='k', label='Filtered')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()

# %%
from scipy.io import wavfile
wavfile.write('TestFiltered.wav', sr, ffilt)

# %% [markdown]
# # TRY 2

# %%
from IPython.display import Audio
f=alcon[73000:85000]
plt.plot(f)
Audio(data=f, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
n=len(f)
fhat= np.fft.fft(f,n)
PSD =fhat * np.conj(fhat)/n 
plt.plot(PSD)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
len(PSD)
V=[]
for i in range(0,len(PSD)):
    if 1000<i<3000:
        V.append(1)
    elif 8000<i<11000:
        V.append(1)
    else:
        V.append(0)
PSD2=PSD*V
plt.plot(PSD2)

# %%
dt=1/n
t = np.arange(0,1,dt)
freq = (1/(dt*n)) * np.arange(n) 
L = np.arange(1,np.floor(n/2), dtype='int') #Only plt the first half

# %%
fig, axs= plt.subplots(2,1)

plt.sca(axs[0])
plt.plot(t,f,color='c', label='Noisy')
plt.xlim(t[0], t[-1])
plt.legend

plt.sca(axs[1])
plt.plot(freq[L],PSD[L],color='c', label='Noisy')
plt.xlim(freq[L[0]], freq[L[-1]])
plt.xlabel('Frecuency in HZ')
plt.ylabel('Power Spectrum')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
indices = PSD >0 #find all frecuencies with  large power
ind=[]
for i in PSD:
    if i<0.0005:
        ind.append(1)
    else:
        ind.append(0)

PSDclean = PSD * V #Zero out all others
fhat = V * fhat # Zero out small Fourier coeffs in Y


ffilt = np.fft.ifft(fhat)  #Inverse

# %%
fig, axs = plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(t,f,color='c', label='Noisy')
plt.xlim(t[0], t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(t,ffilt,color='k', label='Filtered')
plt.xlim(t[0], t[-1])
plt.legend()

plt.sca(axs[2])
plt.plot(freq[L],PSD[L],color='c', label='Noisy')
plt.plot(freq[L],PSDclean[L], color='k', label='Filtered')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()

# %%
Audio(data=ffilt, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
