# %%
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras

# %%
DATASET_PATH= "data.json"

# %%
import json
import numpy as np

def load_data(dataset_path):
    with open(dataset_path, "r") as fp:
        data = json.load(fp)
        
    #Convert list into a numpy array
    
    inputs = np.array(data["mfcc"],dtype=np.float32)
    targets = np.array(data["labels"],dtype=np.float32)
   # np.asarray(X).astype(np.float32)
    
    return inputs, targets

# %%
if __name__=="__main__":
    #load data
    inputs, targets = load_data(DATASET_PATH)
    
    #split the data into train and test sets
    inputs_train, inputs_test, targets_train, targets_test= train_test_split(inputs, targets, test_size=0.3)
    
    #buil the network architecture
    model = keras.Sequential([
        #input layer
        keras.layers.Flatten(input_shape=(inputs.shape[1],inputs.shape[2])),
        # 1st hidden layer
        keras.layers.Dense(512, activation="relu"),
        #2nd hidden layer
        keras.layers.Dense(256, activation="relu"),
        #3rd hidden layer
        keras.layers.Dense(64, activation="relu"),
        #output layer
        keras.layers.Dense(5, activation="softmax")   
    ])
    
    #compile the network
    optimizer = keras.optimizers.Adam(lr=0.0001)
    model.compile(optimizer=optimizer,
                  loss="sparse_categorical_crossentropy",
                  metrics=["accuracy"])
    model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_5 (Flatten)         (None, 780)               0
#
#  dense_12 (Dense)            (None, 512)               399872
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 64)                16448
#
#  dense_15 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 547,973
# Trainable params: 547,973
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train network
model.fit(inputs_train, targets_train,
          validation_data=(inputs_test, targets_test),
          epochs=50, 
          batch_size=32
         )
# Out:
# Epoch 1/50
# 2/2 [==============================] - 1s 162ms/step - loss: 172.9967 - accuracy: 0.1864 - val_loss: 106.5775 - val_accuracy: 0.2308
# Epoch 2/50
# 2/2 [==============================] - 0s 24ms/step - loss: 95.1263 - accuracy: 0.1864 - val_loss: 45.8519 - val_accuracy: 0.3077
# Epoch 3/50
# 2/2 [==============================] - 0s 25ms/step - loss: 52.0928 - accuracy: 0.1525 - val_loss: 37.7585 - val_accuracy: 0.1923
# Epoch 4/50
# 2/2 [==============================] - 0s 26ms/step - loss: 44.7060 - accuracy: 0.2542 - val_loss: 28.8927 - val_accuracy: 0.1538
# Epoch 5/50
# 2/2 [==============================] - 0s 27ms/step - loss: 35.2320 - accuracy: 0.2203 - val_loss: 34.3765 - val_accuracy: 0.2308
# Epoch 6/50
# 2/2 [==============================] - 0s 26ms/step - loss: 34.5700 - accuracy: 0.1695 - val_loss: 23.9133 - val_accuracy: 0.3077
# Epoch 7/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5130 - accuracy: 0.8983 - val_loss: 5.3906 - val_accuracy: 0.5385
# Epoch 25/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3315 - accuracy: 0.9492 - val_loss: 6.1286 - val_accuracy: 0.5385
# Epoch 26/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.2961 - accuracy: 0.9492 - val_loss: 6.4193 - val_accuracy: 0.5385
# Epoch 27/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.1939 - accuracy: 0.9661 - val_loss: 6.3392 - val_accuracy: 0.5385
# Epoch 28/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.1365 - accuracy: 0.9661 - val_loss: 6.0994 - val_accuracy: 0.5385
# Epoch 29/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0947 - accuracy: 0.9661 - val_loss: 6.0170 - val_accuracy: 0.5000
# Epoch 30/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0727 - accuracy: 0.9661 - val_loss: 6.1968 - val_accuracy: 0.4615
# Epoch 31/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0669 - accuracy: 0.9492 - val_loss: 6.3034 - val_accuracy: 0.4231
# Epoch 32/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0510 - accuracy: 0.9661 - val_loss: 6.1666 - val_accuracy: 0.4615
# Epoch 33/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 5.9852 - val_accuracy: 0.4615
# Epoch 34/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 5.8300 - val_accuracy: 0.4615
# Epoch 35/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 5.7182 - val_accuracy: 0.5000
# Epoch 36/50
# 2/2 [==============================] - 0s 29ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 5.6265 - val_accuracy: 0.5000
# Epoch 37/50
# 2/2 [==============================] - 0s 28ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 5.5604 - val_accuracy: 0.5000
# Epoch 38/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 5.5112 - val_accuracy: 0.5000
# Epoch 39/50
# 2/2 [==============================] - 0s 27ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 5.4741 - val_accuracy: 0.5000
# Epoch 40/50
# 2/2 [==============================] - 0s 45ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 5.4500 - val_accuracy: 0.5000
# Epoch 41/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 5.4333 - val_accuracy: 0.5000
# Epoch 42/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 5.4190 - val_accuracy: 0.5000
# Epoch 43/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 5.4113 - val_accuracy: 0.5000
# Epoch 44/50
# 2/2 [==============================] - 0s 24ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 5.4064 - val_accuracy: 0.4615
# Epoch 45/50
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 5.4043 - val_accuracy: 0.4615
# Epoch 46/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.4045 - val_accuracy: 0.4615
# Epoch 47/50
# 2/2 [==============================] - 0s 26ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 5.4058 - val_accuracy: 0.4615
# Epoch 48/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.4079 - val_accuracy: 0.5000
# Epoch 49/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 5.4102 - val_accuracy: 0.5000
# Epoch 50/50
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 5.4117 - val_accuracy: 0.5000
